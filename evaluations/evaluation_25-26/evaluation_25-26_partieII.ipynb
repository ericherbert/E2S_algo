# %% [markdown]
# # Partie II -- Analyse de la mortalité infantile mondiale

# %% [markdown]
# ## Question 1 — Import du fichier et exploration
# Le dossier *child-mortality* est une exctraction de *OurWorldInData*. Identifier le fichier contenant les données, l'importer et décrire ce qu'il contient.

# %% [markdown]
# ## Question 2 — Visualisation pour un pays choisi au hasard
# Afficher la mortalité infantile en fonction du temps

# %% [markdown]
# ## Question 3 — Corrélation entre deux pays européens
# Représenter les mortalités infantiles de ces deux pays, calculer le coefficient de corrélation et conclure.

# %% [markdown]
# ## Question 4 — Corrélation entre un pays Européen et un pays Sud Américain
# Représenter les mortalités infantiles de ces deux pays, calculer le coefficient de corrélation et conclure.
