# %% [markdown]
# # Évaluation du module Python.
# Quelques informations :
#
# 1. L'évaluation est divisée en deux parties indépendantes. Les deux parties doivent faire l'objet d'un envoi séparé. Vous pouvez aborder la partie II, uniquement **après** m'avoir envoyé la partie I.
# 2. **Aucun** document n'est autorisé pour la partie I.
# 5. Vous **devez** utiliser une IA pour la partie II.
# 3. **Les deux rendus** sont attendus sous la forme d'un **jupyter notebook** (menu `File/save Notebook as/` pour enregistrer) **ou d'un pdf** (menu `File/save and export/`) auquel vous donnerez votre nom et que vous m'enverrez par email *eric.herbert@u-paris.fr*. Par exemple: *A-Nonyme-partieI.pdf*

# %% [markdown]
# # Partie I
#
# ## Manipuler un string
# En vous appuyant sur les variables *a* *b* et *c* proposés dans la cellule du dessous, créer et afficher une seule chaine de caractère en ajoutant les espaces pertinents pour afficher exactement *Jeudi 26 fevrier 2026*

# %%
a = '00Jeudi'
b = 26
c = 'fevrier 2026'

# %% [markdown]
# ## À quoi servent les commandes ?
# 1. Ajouter dans la cellule en dessous sous forme de commentaires l'usage des commandes.
# 2. Executer le script

# %%
import numpy as np
z = -2
if z < 0:
    print('erreur z < 0 ')
elif z > 0:
    print('racine de z = ' + str(np.sqrt(z)))
# Out:
# erreur z < 0

# %% [markdown]
# ## Écrire une boucle **for**
# 1. Rappeler à quoi sert et comment s'utilise une boucle `for`
# 2. L'esperance de vie d'une population est de 60 ans. Elle augmente de 0.9% tous les ans pendant 100 ans. A l'aide d'une boucle `for`, calculer l'esperance de vie finale.
# 3. Conclure

# %%
edv = 60
for i in range(100):
    edv = edv + edv*0.9/100
print(edv)
# Out:
# 146.98325950409546

# %% [markdown]
# ## Corriger
# 1. Corriger la cellule suivante pour qu'elle puisse s'executer
# 2. Vérifier que la sortie est correcte, c'est à dire conforme à ce que décrit la documentation. Corriger sinon.
# 3. Combien de kWh dans 278987 Joules ?

# %%
def conv_Joule_kWh( a ) :
    # converti une entrée en Joule en une sortie en Wh
    # argument entreee: a en Joule
    # argument de sortie: surface
    energie =  a / 100 / 3600
    return Wh
conv_joule_Wh()
